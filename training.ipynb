# %% [markdown]
# # Eloss experiments

# %% [markdown]
# ## Can Eloss accelerate training process?

# %% [markdown]
# ### KITTI

# %% [markdown]
# #### Experiment on PointPillar

# %%
# Train without Eloss
# !tools/dist_train.sh configs/eloss/hv_pointpillars_secfpn_fp16_6x8_160e_kitti-3d-car.py 8
# Out:
# /opt/conda/lib/python3.8/site-packages/torch/distributed/launch.py:178: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torch.distributed.run.
# Note that --use_env is set by default in torch.distributed.run.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   warnings.warn(
# WARNING:torch.distributed.run:*****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# /user-data/mmdetection3d/mmdet3d/models/backbones/mink_resnet.py:9: UserWarning: Please follow `getting_started.md` to install MinkowskiEngine.`
# ...

# %%
# Train with Eloss
# !tools/dist_train.sh configs/eloss/hv_pointpillars_secfpn_fp16_6x8_160e_kitti-3d-car-eloss.py 8
# Out:
# /opt/conda/lib/python3.8/site-packages/torch/distributed/launch.py:178: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torch.distributed.run.
# Note that --use_env is set by default in torch.distributed.run.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   warnings.warn(
# WARNING:torch.distributed.run:*****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# /user-data/mmdetection3d/mmdet3d/models/backbones/mink_resnet.py:9: UserWarning: Please follow `getting_started.md` to install MinkowskiEngine.`
# ...

# %% [markdown]
# #### Experiment on VoxelNet

# %%
# Train without Eloss
# !tools/dist_train.sh configs/eloss/hv_second_secfpn_fp16_6x8_80e_kitti-3d-car.py 8
# Out:
# /opt/conda/lib/python3.8/site-packages/torch/distributed/launch.py:178: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torch.distributed.run.
# Note that --use_env is set by default in torch.distributed.run.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   warnings.warn(
# WARNING:torch.distributed.run:*****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# /user-data/mmdetection3d/mmdet3d/models/backbones/mink_resnet.py:9: UserWarning: Please follow `getting_started.md` to install MinkowskiEngine.`
# ...

# %%
# Train with Eloss
# !tools/dist_train.sh configs/eloss/hv_second_secfpn_fp16_6x8_80e_kitti-3d-car-eloss.py 8
# Out:
# /opt/conda/lib/python3.8/site-packages/torch/distributed/launch.py:178: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torch.distributed.run.
# Note that --use_env is set by default in torch.distributed.run.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   warnings.warn(
# WARNING:torch.distributed.run:*****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# /user-data/mmdetection3d/mmdet3d/models/backbones/mink_resnet.py:9: UserWarning: Please follow `getting_started.md` to install MinkowskiEngine.`
# ...

# %% [markdown]
# ### nuScenes

# %% [markdown]
# #### Experiment on PointPillar

# %%
# Train without Eloss
# !tools/dist_train.sh configs/eloss/hv_pointpillars_secfpn_sbn-all_fp16_4x8_2x_nus-3d.py 8 --resume-from work_dirs/hv_pointpillars_secfpn_sbn-all_fp16_4x8_2x_nus-3d/latest.pth
# Out:
# /opt/conda/lib/python3.8/site-packages/torch/distributed/launch.py:178: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torch.distributed.run.
# Note that --use_env is set by default in torch.distributed.run.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   warnings.warn(
# WARNING:torch.distributed.run:*****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# /user-data/mmdetection3d/mmdet3d/models/backbones/mink_resnet.py:9: UserWarning: Please follow `getting_started.md` to install MinkowskiEngine.`
# ...

# %%
# Train with Eloss
# !tools/dist_train.sh configs/eloss/hv_pointpillars_secfpn_sbn-all_fp16_4x8_2x_nus-3d-eloss.py 8 --resume-from work_dirs/hv_pointpillars_secfpn_sbn-all_fp16_4x8_2x_nus-3d-eloss/latest.pth
# Out:
# /opt/conda/lib/python3.8/site-packages/torch/distributed/launch.py:178: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torch.distributed.run.
# Note that --use_env is set by default in torch.distributed.run.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   warnings.warn(
# WARNING:torch.distributed.run:*****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# /user-data/mmdetection3d/mmdet3d/models/backbones/mink_resnet.py:9: UserWarning: Please follow `getting_started.md` to install MinkowskiEngine.`
# ...

# %% [markdown]
# #### Experiment on VoxelNet

# %%
# Train without Eloss
# !tools/dist_train.sh configs/eloss/centerpoint_01voxel_second_secfpn_4x8_cyclic_20e_nus.py 1
# Out:
# /opt/conda/lib/python3.8/site-packages/torch/distributed/launch.py:178: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torch.distributed.run.
# Note that --use_env is set by default in torch.distributed.run.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   warnings.warn(
# /user-data/mmdetection3d/mmdet3d/models/backbones/mink_resnet.py:9: UserWarning: Please follow `getting_started.md` to install MinkowskiEngine.`
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/mmdet/utils/setup_env.py:38: UserWarning: Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
#   warnings.warn(
# ...

# %%
# Train with Eloss
# !tools/dist_train.sh configs/eloss/centerpoint_01voxel_second_secfpn_4x8_cyclic_20e_nus-eloss.py 1
# Out:
# /opt/conda/lib/python3.8/site-packages/torch/distributed/launch.py:178: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torch.distributed.run.
# Note that --use_env is set by default in torch.distributed.run.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   warnings.warn(
# /user-data/mmdetection3d/mmdet3d/models/backbones/mink_resnet.py:9: UserWarning: Please follow `getting_started.md` to install MinkowskiEngine.`
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/mmdet/utils/setup_env.py:38: UserWarning: Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
#   warnings.warn(
# ...

# %% [markdown]
# ## How much Eloss can influence

# %%
import torch

# %% [markdown]
# ### Experiment on PointPillar+KITTI

# %%
# Freeze part of parameters https://blog.csdn.net/qq_21997625/article/details/90369838

model_dict = torch.load('checkpoints/pointpillars_kitti/hv_pointpillars_secfpn_6x8_160e_kitti-3d-car_20220331_134606-d42d15ed.pth')["state_dict"]
dict_name = list(model_dict)
for i, p in enumerate(dict_name):
    print(i, p)
# Out:
# 0 backbone.blocks.0.0.weight
# 1 backbone.blocks.0.1.weight
# 2 backbone.blocks.0.1.bias
# 3 backbone.blocks.0.1.running_mean
# 4 backbone.blocks.0.1.running_var
# 5 backbone.blocks.0.1.num_batches_tracked
# 6 backbone.blocks.0.3.weight
# 7 backbone.blocks.0.4.weight
# 8 backbone.blocks.0.4.bias
# 9 backbone.blocks.0.4.running_mean
# 10 backbone.blocks.0.4.running_var
# 11 backbone.blocks.0.4.num_batches_tracked
# 12 backbone.blocks.0.6.weight
# 13 backbone.blocks.0.7.weight
# 14 backbone.blocks.0.7.bias
# 15 backbone.blocks.0.7.running_mean
# 16 backbone.blocks.0.7.running_var
# 17 backbone.blocks.0.7.num_batches_tracked
# 18 backbone.blocks.0.9.weight
# 19 backbone.blocks.0.10.weight
# 20 backbone.blocks.0.10.bias
# 21 backbone.blocks.0.10.running_mean
# 22 backbone.blocks.0.10.running_var
# 23 backbone.blocks.0.10.num_batches_tracked
# 24 backbone.blocks.1.0.weight
# 25 backbone.blocks.1.1.weight
# 26 backbone.blocks.1.1.bias
# 27 backbone.blocks.1.1.running_mean
# ...

# %% [markdown]
# #### 33% Eloss

# %%
# Train with Eloss
# !tools/dist_train.sh configs/eloss/pointpillars_kitti_eloss33.py 8 --resume-from checkpoints/pointpillars_kitti/hv_pointpillars_secfpn_6x8_160e_kitti-3d-car_20220331_134606-d42d15ed.pth
# Out:
# /opt/conda/lib/python3.8/site-packages/torch/distributed/launch.py:178: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torch.distributed.run.
# Note that --use_env is set by default in torch.distributed.run.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   warnings.warn(
# /user-data/mmdetection3d/mmdet3d/models/backbones/mink_resnet.py:9: UserWarning: Please follow `getting_started.md` to install MinkowskiEngine.`
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/mmdet/utils/setup_env.py:38: UserWarning: Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
#   warnings.warn(
# ...

# %% [markdown]
# #### 66% Eloss

# %%
# Train with Eloss
# !tools/dist_train.sh configs/eloss/pointpillars_kitti_eloss66.py 8 --resume-from work_dirs/

# %% [markdown]
# #### 99% Eloss

# %%
# Train with Eloss
# !tools/dist_train.sh configs/eloss/pointpillars_kitti_eloss99.py 8

# %% [markdown]
# ### Experiment on VoxelNet+KITTI

# %% [markdown]
# #### 50% Eloss

# %%
# Train with Eloss
# !tools/dist_train.sh configs/eloss/voxelnet_kitti_eloss50.py 8 --resume-from checkpoints/second_kitti/hv_second_secfpn_6x8_80e_kitti-3d-car_20200620_230238-393f000c.pth
# Out:
# /opt/conda/lib/python3.8/site-packages/torch/distributed/launch.py:178: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torch.distributed.run.
# Note that --use_env is set by default in torch.distributed.run.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   warnings.warn(
# /user-data/mmdetection3d/mmdet3d/models/backbones/mink_resnet.py:9: UserWarning: Please follow `getting_started.md` to install MinkowskiEngine.`
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/mmdet/utils/setup_env.py:38: UserWarning: Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
#   warnings.warn(
# ...

# %% [markdown]
# #### 100% Eloss

# %%
# Train with Eloss
# !tools/dist_train.sh configs/eloss/voxelnet_kitti_eloss100.py 8
